# %% [markdown]
# # Solution 2
#
# ## FINM 37500 - 2024
#
# ### UChicago Financial Mathematics
#
# * Mark Hendricks
# * hendricks@uchicago.edu

# %% [markdown]
# #### Updated March 4
#
# The stripping of the caps utilizes `flat_to_forward_vol`. Before the update, this function was calling an incorrect version of the function.
#
# With the update, the forward volatilities are corrected, which impacts the pricing info below.

# %% [markdown]
# # 1. Stripping Caps

# %% [markdown]
# The file `data/cap_curves_2024-02-16.xlsx` has market data on the following curves:
# * swap rates (SOFR)
# * discount factors
# * forward rates
# * flat volatilites
#
# A few details
# * the swap and forward rates are quarterly compounded.
# * the flat volatilites are (Black) quotes on caps containing caplets ranging from expiration of $\tau=.5$ to $\tau=T$.
# * the details of the data prep can be found in `build_data/Process Cap Quotes`.

# %% [markdown]
# ## Context
#
# Recall that
# * a cap is made of caplets with $.5\le \tau \le T$
# * the flat volatility at $T$ is input for every caplet corresponding to the cap of $T$.
# * use Black's formula for this calculation.
# * in Black's formula, use $T-0.25$ as the rate for the caplet is determined one period before it is paid.
#
# As for the cap parameters,
# * the cap's strike is the swap rate with the same tenor. So the $T=2$ cap is struck at the swap rate of $\tau=2$.
# * the notional of the cap is $100.
# * the payoff of each caplet is
#
# $$\frac{100}{n}\max(r-K,0)$$
#
# where $n$ is the frequency; here $n=4$.
#
# Thus, the corresponding value in Black's fomula for a caplet is
# $$P^{\text{cap}}_{T} = \frac{100}{n} \sum_{\tau=.5}^T B_{\text{call}}(\overline{\sigma}_T, \tau-.25, K=s_T, f_{\tau}, Z_{\tau})$$
# Note here that for every caplet in cap $T$, we plug in the same
# * flat vol with tenor $T$.
# * strike which is the swap rate of maturity $T$.
#
# The notation above is using subscripts for tenor / maturity rather than time period. That is, $Z_{\tau}$ denotes $Z(t, t+\tau)$ which is today's discount factor for maturity $\tau$. Similarly for the swap rate of tenor $T$, denoted above $s_T$ and forward rate $f(t,t+\tau-.25, t+\tau)$ denoted simply $f_{\tau}$.

# %% [markdown]
# ### Black's Formula
# Recall Black's formula:
#
# $$\begin{align}
# B_{\text{call}}(\sigma, T, K, f, Z) = &\; Z\left[f\mathcal{N}\left(d_1\right) - K\mathcal{N}(d_2)\right] \\
# d_1 =& \frac{\ln\left(\frac{f}{K}\right) + \frac{\sigma^2}{2}T}{\sigma\sqrt{T}} \\
# d_2 =& d_1 -\sigma\sqrt{T}
# \end{align}
# $$

# %% [markdown]
# ## 1.1 Cap Prices
#
# For each cap maturity, $.5\le T \le 10$, use the flat volatility to get the price of the cap.
#
# Report the cap prices across expirations, $.5\le T \le 10$.
#
# Plot the cap prices across expirations.

# %% [markdown]
# ## 1.2 Caplet Prices and Forward Volatilities
#
# Using the cap prices, strip out the
# * caplet prices
# * forward volatility at $\tau$ which properly prices caplet $\tau$ using Black's formula.
#
# List and plot the forward volatility versus the flat volatiltiy.

# %% [markdown]
# ## 1.3 Calibrate a BDT model
#
# Use data from the file `data/cap_curves_2024-02-16.xlsx` to calibrate the BDT model.
# * Use the forward volatilities calculated in 1.2 to calibrate $\sigma$ at each step.
# * You do not have a forward volatility at $\tau=.25$ given there is no caplet there. For purposes of the BDT model, assume $\sigma_{.25}$ is equal to the forward volatility at the first estimated period, $t=0.50$. That is, use the first estimated forward vol (corresponding to $\tau=.50$ for both $t=.25$ and $t=.50$ in the BDT tree.
#
# Given these volatility parameters, calibrate the series of $\theta$ to fit the zero-coupon bond prices given by `discounts` (multiplied by 100).
#
# **Display**
# * the series of $\theta$ parameters.
# * the tree of rates from $0\le t \le 10$.

# %% [markdown]
# ***

# %% [markdown]
# # **<span style="color:red">Solution 1</span>**

# %%
import sys
import os
# sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), 'cmds/'))
sys.path.append(os.path.dirname(os.getcwd()))
from cmds.binomial import *

import numpy as np
import pandas as pd

from cmds.ficcvol import *
from cmds.binomial import *
from cmds.ratecurves import *

# %%
import datetime
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,6)
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 13

from matplotlib.ticker import (MultipleLocator,
                               FormatStrFormatter,
                               AutoMinorLocator)

# %% [markdown]
# ## Stripping Caps

# %%
DATE = '2024-02-16'
curves = pd.read_excel(f'../data/cap_curves_{DATE}.xlsx', sheet_name=f'rate curves {DATE}').set_index('tenor')

# %%
curves
# Out:
#        swap rates  discounts  forwards  flat vols  fwd vols
# tenor
# 0.25     0.053220   0.986870       NaN        NaN       NaN
# 0.50     0.052569   0.974225  0.051917   0.164498  0.164498
# 0.75     0.051547   0.962315  0.049503   0.189530  0.208622
# 1.00     0.050334   0.951210  0.046700   0.214562  0.251768
# 1.25     0.048626   0.941373  0.041799   0.257098  0.355909
# 1.50     0.047222   0.932004  0.040209   0.288577  0.372774
# 1.75     0.046049   0.923001  0.039018   0.310668  0.379028
# 2.00     0.045095   0.914218  0.038426   0.325038  0.375009
# 2.25     0.044138   0.905954  0.036487   0.333356  0.362712
# 2.50     0.043422   0.897654  0.036988   0.337288  0.349289
# 2.75     0.042868   0.889355  0.037327   0.338502  0.338159
# 3.00     0.042457   0.880998  0.037943   0.338666  0.334132
# 3.25     0.041997   0.873037  0.036474   0.339084  0.336180
# 3.50     0.041565   0.865260  0.035952   0.339599  0.338528
# 3.75     0.041275   0.857281  0.037231   0.339694  0.337068
# 4.00     0.041040   0.849316  0.037509   0.338848  0.327652
# 4.25     0.040760   0.841681  0.036285   0.336758  0.310595
# 4.50     0.040499   0.834163  0.036054   0.333989  0.298555
# 4.75     0.040329   0.826459  0.037285   0.331324  0.297018
# 5.00     0.040214   0.818677  0.038022   0.329542  0.305511
# 5.25     0.040098   0.811016  0.037787   0.329151  0.322704
# 5.50     0.039978   0.803493  0.037452   0.329550  0.334361
# 5.75     0.039861   0.796071  0.037288   0.329866  0.333762
# 6.00     0.039756   0.788711  0.037330   0.329223  0.317800
# 6.25     0.039668   0.781374  0.037560   0.327013  0.288683
# 6.50     0.039596   0.774060  0.037792   0.323696  0.264450
# 6.75     0.039535   0.766783  0.037962   0.319999  0.251429
# 7.00     0.039482   0.759557  0.038055   0.316650  0.251810
# 7.25     0.039434   0.752395  0.038075   0.314191  0.264286
# 7.50     0.039389   0.745296  0.038099   0.312427  0.274960
# 7.75     0.039349   0.738256  0.038149   0.310981  0.278950
# 8.00     0.039314   0.731267  0.038226   0.309473  0.274872
# 8.25     0.039284   0.724327  0.038327   0.307612  0.263518
# 8.50     0.039259   0.717434  0.038428   0.305448  0.252540
# 8.75     0.039238   0.710591  0.038520   0.303120  0.244309
# 9.00     0.039220   0.703799  0.038602   0.300762  0.239269
# 9.25     0.039205   0.697061  0.038670   0.298514  0.237884
# 9.50     0.039193   0.690377  0.038722   0.296512  0.240649
# 9.75     0.039181   0.683752  0.038756   0.294892  0.248100
# 10.00    0.039171   0.677189  0.038769   0.293793  0.260833

# %%
capcurves = flat_to_forward_vol(curves)

capcurves[['flat vols','fwd vols']].plot();

# %% [markdown]
# ### Calibrating Theta

# %%
quotes = curves['discounts']*100

# %%
sigmas = capcurves['fwd vols']
sigmas.iloc[0] = sigmas.iloc[1]

theta, ratetree = estimate_theta(sigmas,quotes)
format_bintree(theta.to_frame().T, style='{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2c9c0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >time</th>
#       <th id="T_2c9c0_level0_col0" class="col_heading level0 col0" >0.00</th>
#       <th id="T_2c9c0_level0_col1" class="col_heading level0 col1" >0.25</th>
#       <th id="T_2c9c0_level0_col2" class="col_heading level0 col2" >0.50</th>
#       <th id="T_2c9c0_level0_col3" class="col_heading level0 col3" >0.75</th>
#       <th id="T_2c9c0_level0_col4" class="col_heading level0 col4" >1.00</th>
#       <th id="T_2c9c0_level0_col5" class="col_heading level0 col5" >1.25</th>
#       <th id="T_2c9c0_level0_col6" class="col_heading level0 col6" >1.50</th>
#       <th id="T_2c9c0_level0_col7" class="col_heading level0 col7" >1.75</th>
#       <th id="T_2c9c0_level0_col8" class="col_heading level0 col8" >2.00</th>
#       <th id="T_2c9c0_level0_col9" class="col_heading level0 col9" >2.25</th>
#       <th id="T_2c9c0_level0_col10" class="col_heading level0 col10" >2.50</th>
#       <th id="T_2c9c0_level0_col11" class="col_heading level0 col11" >2.75</th>
#       <th id="T_2c9c0_level0_col12" class="col_heading level0 col12" >3.00</th>
#       <th id="T_2c9c0_level0_col13" class="col_heading level0 col13" >3.25</th>
#       <th id="T_2c9c0_level0_col14" class="col_heading level0 col14" >3.50</th>
#       <th id="T_2c9c0_level0_col15" class="col_heading level0 col15" >3.75</th>
#       <th id="T_2c9c0_level0_col16" class="col_heading level0 col16" >4.00</th>
#       <th id="T_2c9c0_level0_col17" class="col_heading level0 col17" >4.25</th>
#       <th id="T_2c9c0_level0_col18" class="col_heading level0 col18" >4.50</th>
#       <th id="T_2c9c0_level0_col19" class="col_heading level0 col19" >4.75</th>
#       <th id="T_2c9c0_level0_col20" class="col_heading level0 col20" >5.00</th>
#       <th id="T_2c9c0_level0_col21" class="col_heading level0 col21" >5.25</th>
#       <th id="T_2c9c0_level0_col22" class="col_heading level0 col22" >5.50</th>
#       <th id="T_2c9c0_level0_col23" class="col_heading level0 col23" >5.75</th>
#       <th id="T_2c9c0_level0_col24" class="col_heading level0 col24" >6.00</th>
#       <th id="T_2c9c0_level0_col25" class="col_heading level0 col25" >6.25</th>
#       <th id="T_2c9c0_level0_col26" class="col_heading level0 col26" >6.50</th>
#       <th id="T_2c9c0_level0_col27" class="col_heading level0 col27" >6.75</th>
#       <th id="T_2c9c0_level0_col28" class="col_heading level0 col28" >7.00</th>
#       <th id="T_2c9c0_level0_col29" class="col_heading level0 col29" >7.25</th>
#       <th id="T_2c9c0_level0_col30" class="col_heading level0 col30" >7.50</th>
#       <th id="T_2c9c0_level0_col31" class="col_heading level0 col31" >7.75</th>
#       <th id="T_2c9c0_level0_col32" class="col_heading level0 col32" >8.00</th>
#       <th id="T_2c9c0_level0_col33" class="col_heading level0 col33" >8.25</th>
#       <th id="T_2c9c0_level0_col34" class="col_heading level0 col34" >8.50</th>
#       <th id="T_2c9c0_level0_col35" class="col_heading level0 col35" >8.75</th>
#       <th id="T_2c9c0_level0_col36" class="col_heading level0 col36" >9.00</th>
#       <th id="T_2c9c0_level0_col37" class="col_heading level0 col37" >9.25</th>
#       <th id="T_2c9c0_level0_col38" class="col_heading level0 col38" >9.50</th>
#       <th id="T_2c9c0_level0_col39" class="col_heading level0 col39" >9.75</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c9c0_level0_row0" class="row_heading level0 row0" >theta</th>
#       <td id="T_2c9c0_row0_col0" class="data row0 col0" ></td>
#       <td id="T_2c9c0_row0_col1" class="data row0 col1" >-11.18%</td>
#       <td id="T_2c9c0_row0_col2" class="data row0 col2" >-29.62%</td>
#       <td id="T_2c9c0_row0_col3" class="data row0 col3" >-44.17%</td>
#       <td id="T_2c9c0_row0_col4" class="data row0 col4" >-96.03%</td>
#       <td id="T_2c9c0_row0_col5" class="data row0 col5" >-64.37%</td>
#       <td id="T_2c9c0_row0_col6" class="data row0 col6" >-54.44%</td>
#       <td id="T_2c9c0_row0_col7" class="data row0 col7" >-38.46%</td>
#       <td id="T_2c9c0_row0_col8" class="data row0 col8" >-49.59%</td>
#       <td id="T_2c9c0_row0_col9" class="data row0 col9" >-9.02%</td>
#       <td id="T_2c9c0_row0_col10" class="data row0 col10" >0.17%</td>
#       <td id="T_2c9c0_row0_col11" class="data row0 col11" >11.93%</td>
#       <td id="T_2c9c0_row0_col12" class="data row0 col12" >-12.15%</td>
#       <td id="T_2c9c0_row0_col13" class="data row0 col13" >-0.83%</td>
#       <td id="T_2c9c0_row0_col14" class="data row0 col14" >27.02%</td>
#       <td id="T_2c9c0_row0_col15" class="data row0 col15" >21.08%</td>
#       <td id="T_2c9c0_row0_col16" class="data row0 col16" >5.65%</td>
#       <td id="T_2c9c0_row0_col17" class="data row0 col17" >19.09%</td>
#       <td id="T_2c9c0_row0_col18" class="data row0 col18" >40.00%</td>
#       <td id="T_2c9c0_row0_col19" class="data row0 col19" >35.05%</td>
#       <td id="T_2c9c0_row0_col20" class="data row0 col20" >20.19%</td>
#       <td id="T_2c9c0_row0_col21" class="data row0 col21" >15.02%</td>
#       <td id="T_2c9c0_row0_col22" class="data row0 col22" >15.61%</td>
#       <td id="T_2c9c0_row0_col23" class="data row0 col23" >20.20%</td>
#       <td id="T_2c9c0_row0_col24" class="data row0 col24" >27.72%</td>
#       <td id="T_2c9c0_row0_col25" class="data row0 col25" >32.20%</td>
#       <td id="T_2c9c0_row0_col26" class="data row0 col26" >33.55%</td>
#       <td id="T_2c9c0_row0_col27" class="data row0 col27" >31.84%</td>
#       <td id="T_2c9c0_row0_col28" class="data row0 col28" >27.61%</td>
#       <td id="T_2c9c0_row0_col29" class="data row0 col29" >24.58%</td>
#       <td id="T_2c9c0_row0_col30" class="data row0 col30" >23.21%</td>
#       <td id="T_2c9c0_row0_col31" class="data row0 col31" >23.58%</td>
#       <td id="T_2c9c0_row0_col32" class="data row0 col32" >25.41%</td>
#       <td id="T_2c9c0_row0_col33" class="data row0 col33" >26.92%</td>
#       <td id="T_2c9c0_row0_col34" class="data row0 col34" >27.77%</td>
#       <td id="T_2c9c0_row0_col35" class="data row0 col35" >27.95%</td>
#       <td id="T_2c9c0_row0_col36" class="data row0 col36" >27.37%</td>
#       <td id="T_2c9c0_row0_col37" class="data row0 col37" >25.94%</td>
#       <td id="T_2c9c0_row0_col38" class="data row0 col38" >23.58%</td>
#       <td id="T_2c9c0_row0_col39" class="data row0 col39" >20.15%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Rate Tree

# %%
format_bintree(ratetree,style='{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7e6a9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >time</th>
#       <th id="T_7e6a9_level0_col0" class="col_heading level0 col0" >0.00</th>
#       <th id="T_7e6a9_level0_col1" class="col_heading level0 col1" >0.25</th>
#       <th id="T_7e6a9_level0_col2" class="col_heading level0 col2" >0.50</th>
#       <th id="T_7e6a9_level0_col3" class="col_heading level0 col3" >0.75</th>
#       <th id="T_7e6a9_level0_col4" class="col_heading level0 col4" >1.00</th>
#       <th id="T_7e6a9_level0_col5" class="col_heading level0 col5" >1.25</th>
#       <th id="T_7e6a9_level0_col6" class="col_heading level0 col6" >1.50</th>
#       <th id="T_7e6a9_level0_col7" class="col_heading level0 col7" >1.75</th>
#       <th id="T_7e6a9_level0_col8" class="col_heading level0 col8" >2.00</th>
#       <th id="T_7e6a9_level0_col9" class="col_heading level0 col9" >2.25</th>
#       <th id="T_7e6a9_level0_col10" class="col_heading level0 col10" >2.50</th>
#       <th id="T_7e6a9_level0_col11" class="col_heading level0 col11" >2.75</th>
#       <th id="T_7e6a9_level0_col12" class="col_heading level0 col12" >3.00</th>
#       <th id="T_7e6a9_level0_col13" class="col_heading level0 col13" >3.25</th>
#       <th id="T_7e6a9_level0_col14" class="col_heading level0 col14" >3.50</th>
#       <th id="T_7e6a9_level0_col15" class="col_heading level0 col15" >3.75</th>
#       <th id="T_7e6a9_level0_col16" class="col_heading level0 col16" >4.00</th>
#       <th id="T_7e6a9_level0_col17" class="col_heading level0 col17" >4.25</th>
#       <th id="T_7e6a9_level0_col18" class="col_heading level0 col18" >4.50</th>
#       <th id="T_7e6a9_level0_col19" class="col_heading level0 col19" >4.75</th>
#       <th id="T_7e6a9_level0_col20" class="col_heading level0 col20" >5.00</th>
#       <th id="T_7e6a9_level0_col21" class="col_heading level0 col21" >5.25</th>
#       <th id="T_7e6a9_level0_col22" class="col_heading level0 col22" >5.50</th>
#       <th id="T_7e6a9_level0_col23" class="col_heading level0 col23" >5.75</th>
#       <th id="T_7e6a9_level0_col24" class="col_heading level0 col24" >6.00</th>
#       <th id="T_7e6a9_level0_col25" class="col_heading level0 col25" >6.25</th>
#       <th id="T_7e6a9_level0_col26" class="col_heading level0 col26" >6.50</th>
#       <th id="T_7e6a9_level0_col27" class="col_heading level0 col27" >6.75</th>
#       <th id="T_7e6a9_level0_col28" class="col_heading level0 col28" >7.00</th>
#       <th id="T_7e6a9_level0_col29" class="col_heading level0 col29" >7.25</th>
#       <th id="T_7e6a9_level0_col30" class="col_heading level0 col30" >7.50</th>
#       <th id="T_7e6a9_level0_col31" class="col_heading level0 col31" >7.75</th>
#       <th id="T_7e6a9_level0_col32" class="col_heading level0 col32" >8.00</th>
#       <th id="T_7e6a9_level0_col33" class="col_heading level0 col33" >8.25</th>
#       <th id="T_7e6a9_level0_col34" class="col_heading level0 col34" >8.50</th>
#       <th id="T_7e6a9_level0_col35" class="col_heading level0 col35" >8.75</th>
#       <th id="T_7e6a9_level0_col36" class="col_heading level0 col36" >9.00</th>
#       <th id="T_7e6a9_level0_col37" class="col_heading level0 col37" >9.25</th>
#       <th id="T_7e6a9_level0_col38" class="col_heading level0 col38" >9.50</th>
#       <th id="T_7e6a9_level0_col39" class="col_heading level0 col39" >9.75</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e6a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e6a9_row0_col0" class="data row0 col0" >5.29%</td>
#       <td id="T_7e6a9_row0_col1" class="data row0 col1" >5.58%</td>
#       <td id="T_7e6a9_row0_col2" class="data row0 col2" >5.86%</td>
#       <td id="T_7e6a9_row0_col3" class="data row0 col3" >6.18%</td>
#       <td id="T_7e6a9_row0_col4" class="data row0 col4" >6.30%</td>
#       <td id="T_7e6a9_row0_col5" class="data row0 col5" >7.03%</td>
#       <td id="T_7e6a9_row0_col6" class="data row0 col6" >8.05%</td>
#       <td id="T_7e6a9_row0_col7" class="data row0 col7" >9.51%</td>
#       <td id="T_7e6a9_row0_col8" class="data row0 col8" >10.98%</td>
#       <td id="T_7e6a9_row0_col9" class="data row0 col9" >13.67%</td>
#       <td id="T_7e6a9_row0_col10" class="data row0 col10" >17.11%</td>
#       <td id="T_7e6a9_row0_col11" class="data row0 col11" >21.72%</td>
#       <td id="T_7e6a9_row0_col12" class="data row0 col12" >26.23%</td>
#       <td id="T_7e6a9_row0_col13" class="data row0 col13" >32.62%</td>
#       <td id="T_7e6a9_row0_col14" class="data row0 col14" >42.75%</td>
#       <td id="T_7e6a9_row0_col15" class="data row0 col15" >54.63%</td>
#       <td id="T_7e6a9_row0_col16" class="data row0 col16" >67.10%</td>
#       <td id="T_7e6a9_row0_col17" class="data row0 col17" >84.64%</td>
#       <td id="T_7e6a9_row0_col18" class="data row0 col18" >111.02%</td>
#       <td id="T_7e6a9_row0_col19" class="data row0 col19" >143.44%</td>
#       <td id="T_7e6a9_row0_col20" class="data row0 col20" >180.24%</td>
#       <td id="T_7e6a9_row0_col21" class="data row0 col21" >225.20%</td>
#       <td id="T_7e6a9_row0_col22" class="data row0 col22" >281.71%</td>
#       <td id="T_7e6a9_row0_col23" class="data row0 col23" >353.12%</td>
#       <td id="T_7e6a9_row0_col24" class="data row0 col24" >443.32%</td>
#       <td id="T_7e6a9_row0_col25" class="data row0 col25" >554.75%</td>
#       <td id="T_7e6a9_row0_col26" class="data row0 col26" >690.82%</td>
#       <td id="T_7e6a9_row0_col27" class="data row0 col27" >855.89%</td>
#       <td id="T_7e6a9_row0_col28" class="data row0 col28" >1055.30%</td>
#       <td id="T_7e6a9_row0_col29" class="data row0 col29" >1297.62%</td>
#       <td id="T_7e6a9_row0_col30" class="data row0 col30" >1592.35%</td>
#       <td id="T_7e6a9_row0_col31" class="data row0 col31" >1950.30%</td>
#       <td id="T_7e6a9_row0_col32" class="data row0 col32" >2384.03%</td>
#       <td id="T_7e6a9_row0_col33" class="data row0 col33" >2906.86%</td>
#       <td id="T_7e6a9_row0_col34" class="data row0 col34" >3534.83%</td>
#       <td id="T_7e6a9_row0_col35" class="data row0 col35" >4286.97%</td>
#       <td id="T_7e6a9_row0_col36" class="data row0 col36" >5185.45%</td>
#       <td id="T_7e6a9_row0_col37" class="data row0 col37" >6256.26%</td>
#       <td id="T_7e6a9_row0_col38" class="data row0 col38" >7529.75%</td>
#       <td id="T_7e6a9_row0_col39" c

# %% [markdown]
# ***

# %% [markdown]
# # 2. Pricing a Callable Bond with BDT

# %% [markdown]
# ## Freddie Mac
#
# The U.S. has many forms of *agency* debt in addition to *Treasury* debt. The largest of these *agency* issuers are the housing entities commonly referred to as Freddie Mac and Fannie Mae. While technically distinct from the U.S. Treasury, they are widely seen as having the full credit and backing of the Treasury--particularly after the bailouts of 2008.
#
# Thus, we will examine this agency debt as (credit) risk-free, just like Treasury debt.
#
# Consider the Freddie Mac bond
# * Bloomberg Ticker `FHLMC 6 02/21/34 Corp`
# * Bloomberg ID `COZD1131782`
# * CUSIP `3134H1TN3`
#
# Bond description
# * Issued 2024-02-16
# * Matures 2034-02-21
# * Semiannual coupons
# * Coupon rate 6.00%
#
# Note that these bonds are not a niche market. Just this particular bond was issued with \$15 billion face value.

# %% [markdown]
# ## 2.1 Price the Freddie Mac Bond
#
#
# Assume today is `2024-02-16`.
# * The market price on this day is `$99.953`.
# * Approximate the TTM (time-to-maturity) to be exactly 10 years.
#
# Price this bond using the model calibrated from  data.
# * Price it with the BDT model calibrated in the previous problem.
# * Note that the coupons are paid semiannually whereas the tree steps are quarterly.
#
# Report the tree of bond prices, emphasizing the current modeled price.
#
# How does our modeled price compare to the market price?

# %% [markdown]
# ## 2.2 Callable Bond
#
# One important difference between Treasury debt and this bond is that this bond is **callable**
# * Note that the holder of the bond is short this call option; (the issuer has the optionality.)
#
# #### Style
# * (approximately) American style
# * called only on quarterly dates, not any date
# * since our tree is quarterly, this means callable on any date on our tree.
#
# #### Strike
# * Strike is 100.
# * The strike is based on the **clean** price of the bond, meaning the price which does not account for accrued interest.
#     * In pricing the bond in the previous problem, you should have considered the accrued coupons, or dirty prices.
#     * But in analyzing the option, you must consider its moneyness and payoff based on the clean price.
#
# ### Pricing
# Use the BDT model to price this implicit American call option and the resulting callable bond.
# * Note that the price of the callable bond is your answer to the previous question minus this American option.
# * How close is the modeled price to the market quoted price now that you are accounting for the short embedded option?
#
# Does the price of the callable bond ever get above \$100?

# %% [markdown]
# ## 2.3 Exercising the Option
#
# Show a heatmap of the nodes in which the American bond is exercised.
#
# Is it exercised every time it is in-the-money?

# %% [markdown]
# ***

# %% [markdown]
# # **<span style="color:red">Solution 2</span>**

# %% [markdown]
# The approach is to decompose the Freddie Mac callable bond into...
#
# $$\text{callable bond} = \text{vanilla bond} - \text{call option on vanilla bond}$$

# %% [markdown]
# ### Parameters of the Bond

# %%
FACE = 100
T=10
compound = 4
cpn = .06
cpn_freq = 2

STRIKE = 100
CLEANCALL = True

MKTPRICE = 99.953

dt = 1/compound
tsteps = int(T/dt)

# %%
wrapper_bond = lambda r: payoff_bond(r, dt, facevalue=FACE * (1+cpn/cpn_freq))
payoff_call = lambda p: np.maximum(p-STRIKE,0)

# %% [markdown]
# ### Cashflow tree
#
# The cashflows are simply the coupons.
# * We include the final coupon as part of the final payoff function rather than in the cashflow function.

# %%
cftree = construct_bond_cftree(T, compound, cpn)
# cftree

# %% [markdown]
# ## Price the vanilla bond
#
# Timing is that on coupon nodes, the value shown in the tree is **ex-coupon**.
#
# Calculating the dirty prices (total value) is more direct.
#
# But we must translate to the clean prices to compare with the (clean) strike.

# %% [markdown]
# ### Bond price tree (dirty)
#
# Note that the vanilla bond is priced well above par.
# * coupon is 6%
# * swap rate (ytm) at that maturity is less than 4%
#
# The highlighting below shows when it is above or below par value.

# %%
def highlight_values(val,thresh=100):
    if pd.isna(val):
        color = '#d3d3d3'  # Light grey for NaN values
    elif val < thresh:
        color = '#ffcccc'  # Light red
    else:
        color = '#ccffcc'  # Light green
    return f'background-color: {color}'

# %%
bondtree = bintree_pricing(payoff=wrapper_bond, interest_rate_tree=ratetree.iloc[:tsteps,:tsteps], cftree=cftree)
bondtree.style.format('{:.2f}',na_rep='').applymap(highlight_values).format_index('{:.2f}',axis=1)
# Out:
# <style type="text/css">
# #T_65337_row0_col0, #T_65337_row0_col1, #T_65337_row0_col2, #T_65337_row1_col1, #T_65337_row1_col2, #T_65337_row1_col3, #T_65337_row1_col4, #T_65337_row2_col2, #T_65337_row2_col3, #T_65337_row2_col4, #T_65337_row2_col5, #T_65337_row2_col6, #T_65337_row3_col3, #T_65337_row3_col4, #T_65337_row3_col5, #T_65337_row3_col6, #T_65337_row3_col7, #T_65337_row3_col8, #T_65337_row4_col4, #T_65337_row4_col5, #T_65337_row4_col6, #T_65337_row4_col7, #T_65337_row4_col8, #T_65337_row4_col9, #T_65337_row4_col10, #T_65337_row4_col11, #T_65337_row5_col5, #T_65337_row5_col6, #T_65337_row5_col7, #T_65337_row5_col8, #T_65337_row5_col9, #T_65337_row5_col10, #T_65337_row5_col11, #T_65337_row5_col12, #T_65337_row5_col13, #T_65337_row6_col6, #T_65337_row6_col7, #T_65337_row6_col8, #T_65337_row6_col9, #T_65337_row6_col10, #T_65337_row6_col11, #T_65337_row6_col12, #T_65337_row6_col13, #T_65337_row6_col14, #T_65337_row6_col15, #T_65337_row7_col7, #T_65337_row7_col8, #T_65337_row7_col9, #T_65337_row7_col10, #T_65337_row7_col11, #T_65337_row7_col12, #T_65337_row7_col13, #T_65337_row7_col14, #T_65337_row7_col15, #T_65337_row7_col16, #T_65337_row7_col17, #T_65337_row8_col8, #T_65337_row8_col9, #T_65337_row8_col10, #T_65337_row8_col11, #T_65337_row8_col12, #T_65337_row8_col13, #T_65337_row8_col14, #T_65337_row8_col15, #T_65337_row8_col16, #T_65337_row8_col17, #T_65337_row8_col18, #T_65337_row8_col19, #T_65337_row9_col9, #T_65337_row9_col10, #T_65337_row9_col11, #T_65337_row9_col12, #T_65337_row9_col13, #T_65337_row9_col14, #T_65337_row9_col15, #T_65337_row9_col16, #T_65337_row9_col17, #T_65337_row9_col18, #T_65337_row9_col19, #T_65337_row9_col20, #T_65337_row9_col21, #T_65337_row10_col10, #T_65337_row10_col11, #T_65337_row10_col12, #T_65337_row10_col13, #T_65337_row10_col14, #T_65337_row10_col15, #T_65337_row10_col16, #T_65337_row10_col17, #T_65337_row10_col18, #T_65337_row10_col19, #T_65337_row10_col20, #T_65337_row10_col21, #T_65337_row10_col22, #T_65337_row10_col23, #T_65337_row11_col11, #T_65337_row11_col12, #T_65337_row11_col13, #T_65337_row11_col14, #T_65337_row11_col15, #T_65337_row11_col16, #T_65337_row11_col17, #T_65337_row11_col18, #T_65337_row11_col19, #T_65337_row11_col20, #T_65337_row11_col21, #T_65337_row11_col22, #T_65337_row11_col23, #T_65337_row11_col24, #T_65337_row11_col25, #T_65337_row12_col12, #T_65337_row12_col13, #T_65337_row12_col14, #T_65337_row12_col15, #T_65337_row12_col16, #T_65337_row12_col17, #T_65337_row12_col18, #T_65337_row12_col19, #T_65337_row12_col20, #T_65337_row12_col21, #T_65337_row12_col22, #T_65337_row12_col23, #T_65337_row12_col24, #T_65337_row12_col25, #T_65337_row12_col26, #T_65337_row12_col27, #T_65337_row13_col13, #T_65337_row13_col14, #T_65337_row13_col15, #T_65337_row13_col16, #T_65337_row13_col17, #T_65337_row13_col18, #T_65337_row13_col19, #T_65337_row13_col20, #T_65337_row13_col21, #T_65337_row13_col22, #T_65337_row13_col23, #T_65337_row13_col24, #T_65337_row13_col25, #T_65337_row13_col26, #T_65337_row13_col27, #T_65337_row13_col28, #T_65337_row13_col29, #T_65337_row14_col14, #T_65337_row14_col15, #T_65337_row14_col16, #T_65337_row14_col17, #T_65337_row14_col18, #T_65337_row14_col19, #T_65337_row14_col20, #T_65337_row14_col21, #T_65337_row14_col22, #T_65337_row14_col23, #T_65337_row14_col24, #T_65337_row14_col25, #T_65337_row14_col26, #T_65337_row14_col27, #T_65337_row14_col28, #T_65337_row14_col29, #T_65337_row14_col30, #T_65337_row14_col31, #T_65337_row15_col15, #T_65337_row15_col16, #T_65337_row15_col17, #T_65337_row15_col18, #T_65337_row15_col19, #T_65337_row15_col20, #T_65337_row15_col21, #T_65337_row15_col22, #T_65337_row15_col23, #T_65337_row15_col24, #T_65337_row15_col25, #T_65337_row15_col26, #T_65337_row15_col27, #T_65337_row15_col28, #T_65337_row15_col29, #T_65337_row15_col30, #T_65337_row15_col31, #T_65337_row15_col32, #T_65337_row15_col33, #T_65337_row16_col16, #T_65337_row16_col17, #T_65337_row16_col18, #T_65337_row16_col19, #T_65337_row16_col20, #T_65337_row16_col21, #T_65337_row16_col22, #T_653 ...

# %% [markdown]
# #### Clean Prices
#
# We want to compare the (clean) strike to the **clean** bond price. Thus, we need to subtract accrued interest and coupons from the bond value tree.
#
# $$P_{\text{clean}} = P_{\text{dirty}} - C_{\text{accrued int or coupon}}$$
#
# Then, we will use this clean bond price tree as the underlying.

# %%
accint = construct_accint(bondtree.columns.values, compound, cpn)
accint
# cleantree = np.maximum(bondtree.subtract(accint,axis=1),0)

# cleantree.style.format('{:.2f}',na_rep='').applymap(highlight_values).format_index('{:.2f}',axis=1)
# Out:
# 0.00    0.0
# 0.25    1.5
# 0.50    0.0
# 0.75    1.5
# 1.00    0.0
# 1.25    1.5
# 1.50    0.0
# 1.75    1.5
# 2.00    0.0
# 2.25    1.5
# 2.50    0.0
# 2.75    1.5
# 3.00    0.0
# 3.25    1.5
# 3.50    0.0
# 3.75    1.5
# 4.00    0.0
# 4.25    1.5
# 4.50    0.0
# 4.75    1.5
# 5.00    0.0
# 5.25    1.5
# 5.50    0.0
# 5.75    1.5
# 6.00    0.0
# 6.25    1.5
# 6.50    0.0
# 6.75    1.5
# 7.00    0.0
# 7.25    1.5
# 7.50    0.0
# 7.75    1.5
# 8.00    0.0
# 8.25    1.5
# 8.50    0.0
# 8.75    1.5
# 9.00    0.0
# 9.25    1.5
# 9.50    0.0
# 9.75    1.5
# dtype: float64

# %% [markdown]
# ### Compare to straightforward bond pricing
#
# The Freddie Mac bond (ignoring its callable nature) has no credit risk and fixed semiannual coupons. So we can price it directly as we would in FINM 37400.
#
# (The reason we're pricing the vanilla bond on the tree is to set up the pricing of the call option.)
#
# #### Technical note
# These would be closer to matching in a different dataset. `2024-02-16` data has some compounding issues.

# %%
ytm_semi = compound_rate(curves.loc[T,'swap rates'],4,2)
pd.DataFrame([price_bond(ytm_semi, T, cpn),cleantree.iloc[0,0]],index=['bond formula','tree'],columns=['clean price']).style.format('${:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4d82d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d82d_level0_col0" class="col_heading level0 col0" >clean price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d82d_level0_row0" class="row_heading level0 row0" >bond formula</th>
#       <td id="T_4d82d_row0_col0" class="data row0 col0" >$116.92</td>
#     </tr>
#     <tr>
#       <th id="T_4d82d_level0_row1" class="row_heading level0 row1" >tree</th>
#       <td id="T_4d82d_row1_col0" class="data row1 col0" >$116.65</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Value the American Call options
#
# Assuming that the strike on the embedded option is referring to the **clean** price.
#
# Otherwise, try setting the parameter `CLEANCALL` to `False`.

# %%
if CLEANCALL:
    undertree = cleantree
else:
    undertree = bondtree
    
calltree = bintree_pricing(payoff=payoff_call, interest_rate_tree=ratetree.iloc[:tsteps,:tsteps], undertree= undertree, style='american')
format_bintree(calltree)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2aec">
#   <thead>
#     <tr>
#       <th class="index_name level0" >time</th>
#       <th id="T_e2aec_level0_col0" class="col_heading level0 col0" >0.00</th>
#       <th id="T_e2aec_level0_col1" class="col_heading level0 col1" >0.25</th>
#       <th id="T_e2aec_level0_col2" class="col_heading level0 col2" >0.50</th>
#       <th id="T_e2aec_level0_col3" class="col_heading level0 col3" >0.75</th>
#       <th id="T_e2aec_level0_col4" class="col_heading level0 col4" >1.00</th>
#       <th id="T_e2aec_level0_col5" class="col_heading level0 col5" >1.25</th>
#       <th id="T_e2aec_level0_col6" class="col_heading level0 col6" >1.50</th>
#       <th id="T_e2aec_level0_col7" class="col_heading level0 col7" >1.75</th>
#       <th id="T_e2aec_level0_col8" class="col_heading level0 col8" >2.00</th>
#       <th id="T_e2aec_level0_col9" class="col_heading level0 col9" >2.25</th>
#       <th id="T_e2aec_level0_col10" class="col_heading level0 col10" >2.50</th>
#       <th id="T_e2aec_level0_col11" class="col_heading level0 col11" >2.75</th>
#       <th id="T_e2aec_level0_col12" class="col_heading level0 col12" >3.00</th>
#       <th id="T_e2aec_level0_col13" class="col_heading level0 col13" >3.25</th>
#       <th id="T_e2aec_level0_col14" class="col_heading level0 col14" >3.50</th>
#       <th id="T_e2aec_level0_col15" class="col_heading level0 col15" >3.75</th>
#       <th id="T_e2aec_level0_col16" class="col_heading level0 col16" >4.00</th>
#       <th id="T_e2aec_level0_col17" class="col_heading level0 col17" >4.25</th>
#       <th id="T_e2aec_level0_col18" class="col_heading level0 col18" >4.50</th>
#       <th id="T_e2aec_level0_col19" class="col_heading level0 col19" >4.75</th>
#       <th id="T_e2aec_level0_col20" class="col_heading level0 col20" >5.00</th>
#       <th id="T_e2aec_level0_col21" class="col_heading level0 col21" >5.25</th>
#       <th id="T_e2aec_level0_col22" class="col_heading level0 col22" >5.50</th>
#       <th id="T_e2aec_level0_col23" class="col_heading level0 col23" >5.75</th>
#       <th id="T_e2aec_level0_col24" class="col_heading level0 col24" >6.00</th>
#       <th id="T_e2aec_level0_col25" class="col_heading level0 col25" >6.25</th>
#       <th id="T_e2aec_level0_col26" class="col_heading level0 col26" >6.50</th>
#       <th id="T_e2aec_level0_col27" class="col_heading level0 col27" >6.75</th>
#       <th id="T_e2aec_level0_col28" class="col_heading level0 col28" >7.00</th>
#       <th id="T_e2aec_level0_col29" class="col_heading level0 col29" >7.25</th>
#       <th id="T_e2aec_level0_col30" class="col_heading level0 col30" >7.50</th>
#       <th id="T_e2aec_level0_col31" class="col_heading level0 col31" >7.75</th>
#       <th id="T_e2aec_level0_col32" class="col_heading level0 col32" >8.00</th>
#       <th id="T_e2aec_level0_col33" class="col_heading level0 col33" >8.25</th>
#       <th id="T_e2aec_level0_col34" class="col_heading level0 col34" >8.50</th>
#       <th id="T_e2aec_level0_col35" class="col_heading level0 col35" >8.75</th>
#       <th id="T_e2aec_level0_col36" class="col_heading level0 col36" >9.00</th>
#       <th id="T_e2aec_level0_col37" class="col_heading level0 col37" >9.25</th>
#       <th id="T_e2aec_level0_col38" class="col_heading level0 col38" >9.50</th>
#       <th id="T_e2aec_level0_col39" class="col_heading level0 col39" >9.75</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2aec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2aec_row0_col0" class="data row0 col0" >19.07</td>
#       <td id="T_e2aec_row0_col1" class="data row0 col1" >15.06</td>
#       <td id="T_e2aec_row0_col2" class="data row0 col2" >11.52</td>
#       <td id="T_e2aec_row0_col3" class="data row0 col3" >8.51</td>
#       <td id="T_e2aec_row0_col4" class="data row0 col4" >6.06</td>
#       <td id="T_e2aec_row0_col5" class="data row0 col5" >4.15</td>
#       <td id="T_e2aec_row0_col6" class="data row0 col6" >2.73</td>
#       <td id="T_e2aec_row0_col7" class="data row0 col7" >1.72</td>
#       <td id="T_e2aec_row0_col8" class="data row0 col8" >1.03</td>
#       <td id="T_e2aec_row0_col9" class="data row0 col9" >0.59</td>
#       <td id="T_e2aec_row0_col10" class="data row0 col10" >0.31</td>
#       <td id="T_e2aec_row0_col11" class="data row0 col11" >0.16</td>
#       <td id="T_e2aec_row0_col12" class="data row0 col12" >0.07</td>
#       <td id="T_e2aec_row0_col13" class="data row0 col13" >0.03</td>
#       <td id="T_e2aec_row0_col14" class="data row0 col14" >0.01</td>
#       <td id="T_e2aec_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_e2aec_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_e2aec_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_e2aec_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_e2aec_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_e2aec_row0_col20" class="data row0 col20" >0.00</td>
#       <td id="T_e2aec_row0_col21" class="data row0 col21" >0.00</td>
#       <td id="T_e2aec_row0_col22" class="data row0 col22" >0.00</td>
#       <td id="T_e2aec_row0_col23" class="data row0 col23" >0.00</td>
#       <td id="T_e2aec_row0_col24" class="data row0 col24" >0.00</td>
#       <td id="T_e2aec_row0_col25" class="data row0 col25" >0.00</td>
#       <td id="T_e2aec_row0_col26" class="data row0 col26" >0.00</td>
#       <td id="T_e2aec_row0_col27" class="data row0 col27" >0.00</td>
#       <td id="T_e2aec_row0_col28" class="data row0 col28" >0.00</td>
#       <td id="T_e2aec_row0_col29" class="data row0 col29" >0.00</td>
#       <td id="T_e2aec_row0_col30" class="data row0 col30" >0.00</td>
#       <td id="T_e2aec_row0_col31" class="data row0 col31" >0.00</td>
#       <td id="T_e2aec_row0_col32" class="data row0 col32" >0.00</td>
#       <td id="T_e2aec_row0_col33" class="data row0 col33" >0.00</td>
#       <td id="T_e2aec_row0_col34" class="data row0 col34" >0.00</td>
#       <td id="T_e2aec_row0_col35" class="data row0 col35" >0.00</td>
#       <td id="T_e2aec_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_e2aec_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_e2aec_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_e2aec_row0_col39" class="data row0 col39" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2aec_level0_row1" class="row_

# %% [markdown]
# ### Heatmap of the call tree

# %%
sns.heatmap(calltree);

# %% [markdown]
# ### Price vs Market Price

# %%
QUOTE_CALLABLE_CLEAN = MKTPRICE
num_accrued = int((T*compound) %cpn_freq)
quote_callable_dirty = QUOTE_CALLABLE_CLEAN + num_accrued * (cpn/compound)*FACE

callablebondtree = bondtree - calltree
model_price_dirty = callablebondtree.iloc[0,0]
model_price_clean = model_price_dirty - accint.iloc[0]

prices = pd.DataFrame({'clean':[QUOTE_CALLABLE_CLEAN, model_price_clean], 'dirty':[quote_callable_dirty, model_price_dirty]}, index=['market quote','model'])
prices.style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0ce41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ce41_level0_col0" class="col_heading level0 col0" >clean</th>
#       <th id="T_0ce41_level0_col1" class="col_heading level0 col1" >dirty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ce41_level0_row0" class="row_heading level0 row0" >market quote</th>
#       <td id="T_0ce41_row0_col0" class="data row0 col0" >99.95</td>
#       <td id="T_0ce41_row0_col1" class="data row0 col1" >99.95</td>
#     </tr>
#     <tr>
#       <th id="T_0ce41_level0_row1" class="row_heading level0 row1" >model</th>
#       <td id="T_0ce41_row1_col0" class="data row1 col0" >97.57</td>
#       <td id="T_0ce41_row1_col1" class="data row1 col1" >97.57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Callable Bond Tree (dirty)
#
# Note that the bond's price never goes above par plus accrued interest.
# * On coupon dates, the dirty price is displaying inclusive of the coupon.
#
# Why is the price suddenly so much less?
# * The embedded short call option ensures that if the bond's value were high, Freddie Mac would call it back!

# %%
callablebondtree.style.format('{:.2f}',na_rep='').applymap(highlight_values).format_index('{:.2f}',axis=1)
# Out:
# <style type="text/css">
# #T_fe0d8_row0_col0, #T_fe0d8_row0_col1, #T_fe0d8_row0_col2, #T_fe0d8_row0_col3, #T_fe0d8_row0_col4, #T_fe0d8_row0_col5, #T_fe0d8_row0_col6, #T_fe0d8_row0_col7, #T_fe0d8_row0_col8, #T_fe0d8_row0_col9, #T_fe0d8_row0_col10, #T_fe0d8_row0_col11, #T_fe0d8_row0_col12, #T_fe0d8_row0_col13, #T_fe0d8_row0_col14, #T_fe0d8_row0_col15, #T_fe0d8_row0_col16, #T_fe0d8_row0_col17, #T_fe0d8_row0_col18, #T_fe0d8_row0_col19, #T_fe0d8_row0_col20, #T_fe0d8_row0_col21, #T_fe0d8_row0_col22, #T_fe0d8_row0_col23, #T_fe0d8_row0_col24, #T_fe0d8_row0_col25, #T_fe0d8_row0_col26, #T_fe0d8_row0_col27, #T_fe0d8_row0_col28, #T_fe0d8_row0_col29, #T_fe0d8_row0_col30, #T_fe0d8_row0_col31, #T_fe0d8_row0_col32, #T_fe0d8_row0_col33, #T_fe0d8_row0_col34, #T_fe0d8_row0_col35, #T_fe0d8_row0_col36, #T_fe0d8_row0_col37, #T_fe0d8_row0_col38, #T_fe0d8_row0_col39, #T_fe0d8_row1_col2, #T_fe0d8_row1_col3, #T_fe0d8_row1_col4, #T_fe0d8_row1_col5, #T_fe0d8_row1_col6, #T_fe0d8_row1_col7, #T_fe0d8_row1_col8, #T_fe0d8_row1_col9, #T_fe0d8_row1_col10, #T_fe0d8_row1_col11, #T_fe0d8_row1_col12, #T_fe0d8_row1_col13, #T_fe0d8_row1_col14, #T_fe0d8_row1_col15, #T_fe0d8_row1_col16, #T_fe0d8_row1_col17, #T_fe0d8_row1_col18, #T_fe0d8_row1_col19, #T_fe0d8_row1_col20, #T_fe0d8_row1_col21, #T_fe0d8_row1_col22, #T_fe0d8_row1_col23, #T_fe0d8_row1_col24, #T_fe0d8_row1_col25, #T_fe0d8_row1_col26, #T_fe0d8_row1_col27, #T_fe0d8_row1_col28, #T_fe0d8_row1_col29, #T_fe0d8_row1_col30, #T_fe0d8_row1_col31, #T_fe0d8_row1_col32, #T_fe0d8_row1_col33, #T_fe0d8_row1_col34, #T_fe0d8_row1_col35, #T_fe0d8_row1_col36, #T_fe0d8_row1_col37, #T_fe0d8_row1_col38, #T_fe0d8_row1_col39, #T_fe0d8_row2_col4, #T_fe0d8_row2_col5, #T_fe0d8_row2_col6, #T_fe0d8_row2_col7, #T_fe0d8_row2_col8, #T_fe0d8_row2_col9, #T_fe0d8_row2_col10, #T_fe0d8_row2_col11, #T_fe0d8_row2_col12, #T_fe0d8_row2_col13, #T_fe0d8_row2_col14, #T_fe0d8_row2_col15, #T_fe0d8_row2_col16, #T_fe0d8_row2_col17, #T_fe0d8_row2_col18, #T_fe0d8_row2_col19, #T_fe0d8_row2_col20, #T_fe0d8_row2_col21, #T_fe0d8_row2_col22, #T_fe0d8_row2_col23, #T_fe0d8_row2_col24, #T_fe0d8_row2_col25, #T_fe0d8_row2_col26, #T_fe0d8_row2_col27, #T_fe0d8_row2_col28, #T_fe0d8_row2_col29, #T_fe0d8_row2_col30, #T_fe0d8_row2_col31, #T_fe0d8_row2_col32, #T_fe0d8_row2_col33, #T_fe0d8_row2_col34, #T_fe0d8_row2_col35, #T_fe0d8_row2_col36, #T_fe0d8_row2_col37, #T_fe0d8_row2_col38, #T_fe0d8_row2_col39, #T_fe0d8_row3_col6, #T_fe0d8_row3_col7, #T_fe0d8_row3_col8, #T_fe0d8_row3_col9, #T_fe0d8_row3_col10, #T_fe0d8_row3_col11, #T_fe0d8_row3_col12, #T_fe0d8_row3_col13, #T_fe0d8_row3_col14, #T_fe0d8_row3_col15, #T_fe0d8_row3_col16, #T_fe0d8_row3_col17, #T_fe0d8_row3_col18, #T_fe0d8_row3_col19, #T_fe0d8_row3_col20, #T_fe0d8_row3_col21, #T_fe0d8_row3_col22, #T_fe0d8_row3_col23, #T_fe0d8_row3_col24, #T_fe0d8_row3_col25, #T_fe0d8_row3_col26, #T_fe0d8_row3_col27, #T_fe0d8_row3_col28, #T_fe0d8_row3_col29, #T_fe0d8_row3_col30, #T_fe0d8_row3_col31, #T_fe0d8_row3_col32, #T_fe0d8_row3_col33, #T_fe0d8_row3_col34, #T_fe0d8_row3_col35, #T_fe0d8_row3_col36, #T_fe0d8_row3_col37, #T_fe0d8_row3_col38, #T_fe0d8_row3_col39, #T_fe0d8_row4_col8, #T_fe0d8_row4_col9, #T_fe0d8_row4_col10, #T_fe0d8_row4_col11, #T_fe0d8_row4_col12, #T_fe0d8_row4_col13, #T_fe0d8_row4_col14, #T_fe0d8_row4_col15, #T_fe0d8_row4_col16, #T_fe0d8_row4_col17, #T_fe0d8_row4_col18, #T_fe0d8_row4_col19, #T_fe0d8_row4_col20, #T_fe0d8_row4_col21, #T_fe0d8_row4_col22, #T_fe0d8_row4_col23, #T_fe0d8_row4_col24, #T_fe0d8_row4_col25, #T_fe0d8_row4_col26, #T_fe0d8_row4_col27, #T_fe0d8_row4_col28, #T_fe0d8_row4_col29, #T_fe0d8_row4_col30, #T_fe0d8_row4_col31, #T_fe0d8_row4_col32, #T_fe0d8_row4_col33, #T_fe0d8_row4_col34, #T_fe0d8_row4_col35, #T_fe0d8_row4_col36, #T_fe0d8_row4_col37, #T_fe0d8_row4_col38, #T_fe0d8_row4_col39, #T_fe0d8_row5_col12, #T_fe0d8_row5_col13, #T_fe0d8_row5_col14, #T_fe0d8_row5_col15, #T_fe0d8_row5_col16, #T_fe0d8_row5_col17, #T_fe0d8_row5_col18, #T_fe0d8_row5_col19, #T_fe0d8_row5_col20, #T_fe0d8_row5_col21, #T_fe0d8_row5_col22, #T_fe0d8_row5_col23 ...
#   background-color: #ffcccc;
# }
# #T_fe0d8_row1_col0, #T_fe0d8_row2_col0, #T_fe0

# %%
sns.heatmap(callablebondtree);

# %% [markdown]
# #### Compare
# to the heatmap of the value of the vanilla (non-callable) bond.

# %%
sns.heatmap(bondtree);

# %% [markdown]
# ### Optimal Exercise

# %%
temp_ITM = undertree > STRIKE
temp_exer = exercise_decisions(payoff_call,undertree,calltree)
temp = (1*temp_ITM+temp_exer*2).where(calltree.notna(), np.nan)

# %%
ax = sns.heatmap(-temp,square=True);

colorbar = ax.collections[0].colorbar
colorbar.set_ticks([-3, -1, 0])  # Set the positions of the ticks
colorbar.set_ticklabels(['ITM, exercise', 'ITM, dont exercise', 'OTM'])  # Set the tick labels

plt.show()

# %% [markdown]
# ### Technical Point: Overpriced?
#
# Our modeled price of the callable bond is lower than the market's quoted price.
#
# Our model could be poorly...
# * **calibrated** (to the caps, swaps, etc.)
# * **implemented** (time grid, interpolated rate curves, etc.)
#
# The market could be mispricing these bonds!
# * Callable bonds are seemingly overpriced in many situations.
# * Perhaps the issuer does not exercise (call) at optimal times.
# * Why might this overpricing be hard to arbitrage?
# * Francis Longstaff (1992) has a good discussion of mispriced callable Treasury bonds.

# %% [markdown]
# ***

# %% [markdown]
# # 3. Option Adjusted Spread
#
# *This section is optional. No need to submit it, but we will likely discuss it in class.*

# %% [markdown]
# ## 3.1 Calculate the OAS
#
# The **option adjusted spread** is the spread one would need to add to the spot curve, (the discounts), to get the modeled price to match the market price of the derivative. That is, how many bps would you need to add or subtract to all the spot rates in order to perfectly price this callable bond?
#
# * Ignore the effect of the parallel shift in rates on the forward vols. (No need to recalculate section 1.)
#
# * Use the parallel shifts to recalibrate the $\theta$ parameters in the BDT tree.
#
# Report the OAS needed to add (or subtract) in a parallel shift in spot to correctly model the callable bond.
#
# #### Note:
# This **OAS** is a common way to quote whether a derivative seems to be undervalued (positive OAS) or overvalued (negative OAS.) Of course, the OAS is dependent on our modeling choices, so it could also indicate the model is bad.
#
# ## 3.2 Convexity
#
# Continue with parallel shifts of the (present, market quoted) yield curve.
# * Plot the relationship between the value of the callable bond as the spot curve shifts higher and lower.
# * Do you see convexity in this relationship?

# %% [markdown]
# ***

# %% [markdown]
# # **<span style="color:red">Solution 3</span>**

# %% [markdown]
# ### Warning: solutions take several minutes to run

# %%
def wrapper_callable_price(dr):
    quotes = ratecurve_to_discountcurve(curves['swap rates'].loc[:T] + dr, n_compound=compound)*FACE
    error = quote_callable_dirty - price_callable(quotes.loc[:T], sigmas.loc[:T], cftree, accint,  wrapper_bond, payoff_call, cleanstrike=CLEANCALL)
    return error

# %%
from IPython.display import display, HTML

# %%
oas = fsolve(wrapper_callable_price, 0)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 oas = fsolve(wrapper_callable_price, 0)[0]
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# --> 166 res = _root_hybr(func, x0, args, jac=fprime, **options)
#     167 if full_output:
#     168     x = res['x']
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:243, in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     241     if maxfev == 0:
#     242         maxfev = 200 * (n + 1)
# --> 243     retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
#     244                              ml, mu, epsfcn, factor, diag)
#     245 else:
#     246     _check_func('fsolve', 'fprime', Dfun, x0, args, n, (n, n))
#
# Cell In[44], line 3, in wrapper_callable_price(dr)
#       1 def wrapper_callable_price(dr):
#       2     quotes = ratecurve_to_discountcurve(curves['swap rates'].loc[:T] + dr, n_compound=compound)*FACE
# ----> 3     error = quote_callable_dirty - price_callable(quotes.loc[:T], sigmas.loc[:T], cftree, accint,  wrapper_bond, payoff_call, cleanstrike=CLEANCALL)
#       4     return error
#
# File c:\Users\Alex\Desktop\Academic\UChicago\FINM 37500\finm-fiderivs-2024\cmds\binomial.py:364, in price_callable(quotes, fwdvols, cftree, accint, wrapper_bond, payoff_call, cleanstrike)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\Alex\Desktop\Academic\UChicago\FINM 37500\finm-fiderivs-2024\cmds\binomial.py:276, in estimate_theta(sigmas, quotes_zeros, dt, T)
#     273 subtree = ratetree.iloc[:tsteps+1,:tsteps+1]
#     274 wrapper = lambda theta: incremental_BDT_pricing(subtree, theta, sigmas.iloc[tsteps]).loc[0,0] - quotes_zeros.iloc[tsteps] * 100 / scale
# --> 276 theta.iloc[tsteps] = fsolve(wrapper,.5)[0]
#     277 ratetree.iloc[:tsteps+1,tsteps] = incrementBDTtree(subtree, theta.iloc[tsteps], sigmas.iloc[tsteps]).iloc[:,tsteps]
#     279 #print(f'Completed: {tsteps/len(quotes_zeros.index):.1%}')
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# --> 166 res = _root_hybr(func, x0, args, jac=fprime, **options)
#     167 if full_output:
#     168     x = res['x']
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:243, in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     241     if maxfev == 0:
#     242         maxfev = 200 * (n + 1)
# --> 243     retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
#     244                              ml, mu, epsfcn, factor, diag)
#     245 else:
#     246     _check_func('fsolve', 'fprime', Dfun, x0, args, n, (n, n))
#
# File c:\Users\Alex\Desktop\Academic\UChicago\FINM 37500\finm-fiderivs-2024\cmds\binomial.py:274, in estimate_theta.<locals>.<lambda>(theta)
#     272 else:
#     273     subtree = ratetree.iloc[:tsteps+1,:tsteps+1]
# --> 274     wrapper = lambda theta: incremental_BDT_pricing(subtree, theta, sigmas.iloc[tsteps]).loc[0,0] - quotes_zeros.iloc[tsteps] * 100 / scale
#     276     theta.iloc[tsteps] = fsolve(wrapper,.5)[0]
#     277     ratetree.iloc[:tsteps+1,tsteps] = incrementBDTtree(subtree, theta.iloc[tsteps], sigmas.iloc[tsteps]).iloc[:,tsteps]
#
# File c:\Users\Alex\Desktop\Academic\UChicago\FINM 37500\finm-fiderivs-2024\cmds\binomial.py:246, in incremental_BDT_pricing(tree, theta, sigma_new, dt)
#     244 payoff = lambda r: payoff_bond(r,dt)
#     245 newtree = incrementBDTtree(tree, theta, sigma_new)
# --> 246 model_price = bintree_pricing(payoff, newtree)
#     247 return model_price
#
# File c:\Users\Alex\Desktop\Academic\UChicago\FINM 37500\finm-fiderivs-2024\cmds\binomial.py:159, in bintree_pricing(payoff, interest_rate_tree, undertree, cftree, dt, pstars, timing, cfdelay, style, Tamerican)
#     156         cf = cftree.iloc[state,-steps_back]
#     158     # Discounted Expectation + any cashflows
# --> 159     valuetree.loc[state,t] = np.exp(-interest_rate_tree.loc[state,t]*dt) * (val_avg + cf)
#     161 if style=='american':
#     162     if t>= Tamerican:
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:912, in _LocationIndexer.__setitem__(self, key, value)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1946, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1943 # align and set the values
#    1944 if take_split_path:
#    1945     # We have to operate column-wise
# -> 1946     self._setitem_with_indexer_split_path(indexer, value, name)
#    1947 else:
#    1948     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:2039, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2036 else:
#    2037     # scalar value
#    2038     for loc in ilocs:
# -> 2039         self._setitem_single_column(loc, value, pi)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:2168, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2164         self.obj.isetitem(loc, value)
#    2165 else:
#    2166     # set value into the column (first attempting to operate inplace, then
#    2167     #  falling back to casting if necessary)
# -> 2168     self.obj._mgr.column_setitem(loc, plane_indexer, value)
#    2170 self.obj._clear_item_cache()
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1339, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1337 else:
#    1338     new_mgr = col_mgr.setitem((idx,), value)
# -> 1339     self.iset(loc, new_mgr._block.values, inplace=True)
#    1341 if needs_to_warn:
#    1342     warnings.warn(
#    1343         COW_WARNING_GENERAL_MSG,
#    1344         FutureWarning,
#    1345         stacklevel=find_stack_level(),
#    1346     )
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1150, in BlockManager.iset(self, loc, value, inplace, refs)
#    1148     else:
#    1149         blk.set_inplace(blk_locs, value_getitem(val_locs))
# -> 1150         continue
#    1151 else:
#    1152     unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# KeyboardInterrupt:

# %%
pd.DataFrame([oas],columns=['option adjusted spread'],index=['freddie mac bond']).style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9441">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9441_level0_col0" class="col_heading level0 col0" >option adjusted spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9441_level0_row0" class="row_heading level0 row0" >freddie mac bond</th>
#       <td id="T_a9441_row0_col0" class="data row0 col0" >-0.55%</td>
#     </tr>
#   </tbody>
# </table>

# %%
display(HTML(f"<strong><span> The OAS for pricing the callable bond is</span></strong> <strong><span style='color: red'>{oas:.2%}</span></strong>"))
# Out:
# <strong><span> The OAS for pricing the callable bond is</span></strong> <strong><span style='color: red'>-0.55%</span></strong>

# %% [markdown]
# Verify that OAS brings modeled price to match market price
#
# Shift the swap curve by the OAS spread and check that model price is same as the market quote.

# %%
quotes = ratecurve_to_discountcurve(curves['swap rates'].loc[:T] + oas, n_compound=compound)*FACE
prices.loc['model w/ oas','dirty'] = price_callable(quotes.loc[:T], sigmas.loc[:T], cftree, accint,  wrapper_bond, payoff_call, cleanstrike=CLEANCALL)
prices.style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6167">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6167_level0_col0" class="col_heading level0 col0" >clean</th>
#       <th id="T_a6167_level0_col1" class="col_heading level0 col1" >dirty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6167_level0_row0" class="row_heading level0 row0" >market quote</th>
#       <td id="T_a6167_row0_col0" class="data row0 col0" >99.95</td>
#       <td id="T_a6167_row0_col1" class="data row0 col1" >99.95</td>
#     </tr>
#     <tr>
#       <th id="T_a6167_level0_row1" class="row_heading level0 row1" >model</th>
#       <td id="T_a6167_row1_col0" class="data row1 col0" >98.94</td>
#       <td id="T_a6167_row1_col1" class="data row1 col1" >98.94</td>
#     </tr>
#     <tr>
#       <th id="T_a6167_level0_row2" class="row_heading level0 row2" >model w/ oas</th>
#       <td id="T_a6167_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_a6167_row2_col1" class="data row2 col1" >99.95</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **<span style="color:red">3.2</span>**

# %% [markdown]
# #### Get reaction curve

# %%
dr_inc = .0025
drvec = np.arange(-.0250,.0275,dr_inc)

# %%
tsteps = int(T/dt)

cftree = construct_bond_cftree(T,compound,cpn)
accint = construct_accint(cftree.columns.values, compound, cpn)

# %% [markdown]
# Loop through possible rate shifts, repricing callable bond via BDT.

# %%
ytm = curves.loc[T,'swap rates']

modpx = pd.Series(dtype=float, index=drvec+ytm, name='callable')
for numdr, dr in enumerate(drvec):
    quotes = ratecurve_to_discountcurve(curves['swap rates'].loc[:T] + dr, n_compound=compound)*FACE
    modpx.loc[dr+ytm] = price_callable(quotes.loc[:T], sigmas.loc[:T], cftree, accint,  wrapper_bond, payoff_call,cleanstrike=CLEANCALL)

# %% [markdown]
# #### Compare to non-callable bond

# %%
pxvanilla = pd.Series(dtype=float, index=(drvec+ytm),name='non-callable')
for dr in drvec:
    pxvanilla.loc[dr+ytm] = price_bond(ytm_semi+dr, T, cpn, accr_frac=.5)

# %%
tab_comp = pd.concat([pxvanilla,modpx],axis=1)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

tab_comp['callable'].plot(ax=axes[0], title='callable bond',xlabel=f'Swap rate: {T} year maturity');
axes[0].axvline(x=ytm_semi, color='red', linestyle='--')

tab_comp['non-callable'].plot(ax=axes[1], title='non-callable bond',xlabel=f'Swap rate: {T} year maturity');
axes[1].axvline(x=ytm_semi, color='red', linestyle='--')

plt.show()

# %%
tab_comp.plot(xlabel=f'Swap rate: {T} year maturity')
plt.show()

# %% [markdown]
# Note a few things
# * there is negative convexity in the callable bond
# * callable bond's price is lower at all rate levels
# * callable bond's value does not go above par for any rate level

# %% [markdown]
# ### Technical Note: Alternate Ways to Compute OAS
#
# Overall, OAS is based on
# * changing the discounting
# * not changing the cashflows
#
# For this bond, the cashflows are not dependent on the interest rate anyway. But in case of other derivatives where cashflows depend on the rate, (swaptions, etc.) the shift of the discounts should only be applied to the pricing via the discounting, not the cashflows.
